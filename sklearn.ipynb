# %% [markdown]
# <a href="https://colab.research.google.com/github/Roshan21424/ai-machine-learning/blob/main/sklearn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_diabetes

# %%
# sklearn datasets loaders returns a bunch object( like a dictionary object)
# it contains keys like
# data,target,frame,DESCR,feature_names,data_filename,target_file,data_module

bunch = load_diabetes()
type(bunch)

# get the keys of bunch
print(bunch.keys())

# get feature names
print(bunch.feature_names) # ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']

# get target name(read and interprit)
print(bunch.DESCR) # ['disease progression one year after baseline']

"""
how to read and interprit the data?

inputs(x)
- feature_columns => input features names
- data => input features data ( numpy array )

outputs(y)
- DESCR => output feature name(can be figured out)
- target => output feature data ( numpy array )
"""
# Out:
# dict_keys(['data', 'target', 'frame', 'DESCR', 'feature_names', 'data_filename', 'target_filename', 'data_module'])
# ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
# :Number of Instances: 442
#
# :Number of Attributes: First 10 columns are numeric predictive values
#
# :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
# :Attribute Information:
#     - age     age in years
#     - sex
#     - bmi     body mass index
#     - bp      average blood pressure
#     - s1      tc, total serum cholesterol
#     - s2      ldl, low-density lipoproteins
# ...
